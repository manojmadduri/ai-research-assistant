# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["# RAG Evaluation Notebook\nMeasure the performance of your retrieval pipeline."]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Example: compare top-k search results\nfrom rag.retriever import search_documents\n\nquery = 'What is LangChain?'\nresults = search_documents(query)\nprint(results)"
   ]
  }
 ],
 "metadata": {},
 "nbformat": 4,
 "nbformat_minor": 2
}
